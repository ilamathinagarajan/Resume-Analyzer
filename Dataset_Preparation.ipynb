# %%
import pandas as pd

# Generate sample data for the dataset
data = {
    "Resume Skills": [
        [ "Data Analysis", "SQL"],
        ["Java", "Hibernate", "MySQL"],
        ["HTML", "JavaScript", "React"],
        ["Docker", "Kubernetes", "AWS"],
        ["Python", "Pandas", "Data Visualization"],
        ["Java", "REST", "Microservices", "Cloud"],
        ["HTML", "CSS", "Node.js", "Express"],
        [ "Deep Learning", "TensorFlow", "Keras"],
        ["JavaScript", "React", "Redux"],
        ["SQL", "Data Analysis", "Excel"],
        ["Python", "Scrapy", "Beautiful Soup", "APIs"],
        ["Java", "Spring Boot", "JPA", "PostgreSQL"],
        [ "Angular", "TypeScript"],
        ["C++", "Algorithms", "Data Structures", "Python"],
        ["DevOps", "Jenkins", "Terraform"],
        ["Python", "Machine Learning", "Scikit-learn", "Pandas"],
        ["Oracle", "SQL", "Microservices"],
        ["HTML", "CSS", "Bootstrap", "JavaScript"],
        ["Python", "Data Science", "Statistics", "Matplotlib"],
        ["Java", "JavaFX", "Maven", "JUnit"],
        ["JavaScript", "Vue.js", "Nuxt.js", "API Integration"],
        ["Python", "FastAPI", "Machine Learning", "Docker"],
        ["Java", "REST API", "Spring Cloud", "AWS"],
        ["HTML", "CSS", "React", "Redux"],
        ["Python", "Tableau", "Business Intelligence"],
        ["Java", "Eclipse", "JUnit", "MySQL"],
        ["Python", "Flask", "APIs", "SQLAlchemy"],
        ["JavaScript", "Node.js", "Express", "MongoDB"],
        ["Python", "NLP", "SpaCy", "Text Analysis"],
        ["Java", "Struts", "Hibernate", "SQL"],
        ["HTML", "CSS", "JavaScript", "Frontend Development"],
        ["Python", "Big Data", "Spark", "Hadoop"],
        ["Java", "Kafka", "Microservices", "Spring"],
        ["Python", "Data Cleaning", "Pandas", "NumPy"],
        ["JavaScript", "API Development", "Frontend"],
        ["Java", "Web Development","Tomcat"],
        ["Python", "Statistical Analysis", "Data Mining"],
        ["Java", "Spring MVC", "Oracle"],
        ["HTML", "CSS", "JavaScript", "Responsive Design"],
        ["Python", "Data Wrangling", "Pandas", "NLP"],
        ["Java", "Golang", "Cloud", "Microservices"],
        ["JavaScript", "Sass", "Vue.js"],
        ["Python", "ML Ops", "Deployment", "AWS"],
        [ "Spring Framework", "MongoDB", "REST API"],
        ["Python","Java"],
        ["Python", "Data Visualization"],
        ["Java", "JSP", "Servlets", "MySQL"],
        ["JavaScript", "WebSockets", "Node.js"],
        ["Python", "Statistical Modeling", "Machine Learning"],
        ["JavaScript", "Machine Learning", "Statistics"],
        ["Python", "Machine Learning"],
    ["Java", "Spring", "Hibernate", "MySQL"],
    ["JavaScript", "HTML", "CSS"],
    ["PHP", "MySQL", "WordPress"],
    ["Bootstrap", "HTML", "CSS"],
    ["C++", "Data Structures", "Algorithms"],
    ["Node.js", "Express", "MongoDB"],
    ["Ruby", "Ruby on Rails", "SQL"],
    ["C#", ".NET", "SQL Server"],
    ["Swift", "iOS Development"],
    ["Kotlin", "Android Development"],
    ["R", "Statistics", "Data Visualization"],
    ["TensorFlow", "Deep Learning"],
    ["Git", "GitHub", "Version Control"],
    ["DevOps"],
    ["Tableau", "Data Analysis"],
    ["Agile", "Scrum", "Lean"],
    ["SEO", "Digital Marketing"],
    ["React","JavaScript"],
    ["Angular", "Javascript", "Frontend Development"],
    ["Java"],
    ["Swift", "iOS"],
    ["Game Development", "C#"],
    ["Cloud Computing"],
    ["PHP", "Laravel", "Web Development"],
    [ "Data Analysis", "SQL"],
        ["Java", "Hibernate", "MySQL"],
        ["HTML", "JavaScript", "React"],
        ["Docker", "Kubernetes", "AWS"],
        ["Python", "Pandas", "Data Visualization"],
        ['Machine Learning', 'Spring Boot', 'Game Development'],
        ['Figma', 'Scikit-learn'],
        ['Scrum', 'PHP', 'Cloud Computing','GitHub'],
        ['Data Visualization', 'MySQL'],
        ['Game Development'],
        ["Python", "Scrapy", "Beautiful Soup", "APIs"],
        ["Java", "Spring Boot", "JPA", "PostgreSQL"],
        ['Redux', 'Hadoop', 'Cloud Computing'],
        ['Angular', 'GraphQL', 'REST API'],
        ['Data Mining', 'Postman', 'WebSockets', 'MongoDB', 'Big Data'],
        ['TensorFlow', 'Data Science'],
        ['WordPress', 'Maven', 'TensorFlow', 'C#', 'Express'],
        ["HTML", "CSS", "Bootstrap", "JavaScript"],
        ["Python", "Data Science", "Statistics", "Matplotlib"],
        ["Java", "JavaFX", "Maven", "JUnit"],
        ["JavaScript", "Vue.js", "Nuxt.js", "API Integration"],
        ["Python", "FastAPI", "Machine Learning", "Docker"],
        ["Java", "REST API", "Spring Cloud", "AWS"],
        ["HTML", "CSS", "React", "Redux"],
        ["Python", "Tableau", "Business Intelligence"],
        ["Java", "Eclipse", "JUnit", "MySQL"],
        ["Python", "Flask", "APIs", "SQLAlchemy"],
        ["JavaScript", "Node.js", "Express", "MongoDB"],
        ["Python", "NLP", "SpaCy", "Text Analysis"],
        ["Java", "Struts", "Hibernate", "SQL"],
        ["HTML", "CSS", "JavaScript", "Frontend Development"],
        ["Python", "Big Data", "Spark", "Hadoop"],
        ["Java", "Kafka", "Microservices", "Spring"],
        ["Python", "Data Cleaning", "Pandas", "NumPy"],
        ["JavaScript", "API Development", "Frontend"],
        ["Java", "Web Development","Tomcat"],
        ["Python", "Statistical Analysis", "Data Mining"],
        ["Java", "Spring MVC", "Oracle"],
        ["HTML", "CSS", "JavaScript", "Responsive Design"],
        ["Python", "Data Wrangling", "Pandas", "NLP"],
        ["Java", "Golang", "Cloud", "Microservices"],
        ["JavaScript", "Sass", "Vue.js"],
        ["Python", "ML Ops", "Deployment", "AWS"],
        [ "Spring Framework", "MongoDB", "REST API"],
        ["Python","Java"],
        ["Python", "Data Visualization"],
        ["Java", "JSP", "Servlets", "MySQL"],
        ["JavaScript", "WebSockets", "Node.js"],
        ["Python", "Statistical Modeling", "Machine Learning"],
        ["JavaScript", "Machine Learning", "Statistics"],
        ["Python", "Machine Learning"],
        ["Java", "Spring", "Hibernate", "MySQL"],
        ["JavaScript", "HTML", "CSS"],
        ["PHP", "MySQL", "WordPress"],
        ["Bootstrap", "HTML", "CSS"],
        ["C++", "Data Structures", "Algorithms"],
        ["Node.js", "Express", "MongoDB"],
        ["Ruby", "Ruby on Rails", "SQL"],
        ["C#", ".NET", "SQL Server"],
        ["Swift", "iOS Development"],
        ["Kotlin", "Android Development"],
        ["R", "Statistics", "Data Visualization"],
        ["TensorFlow", "Deep Learning"],
        ["Git", "GitHub", "Version Control"],
        ["Docker", "Kubernetes", "DevOps"],
        ["Power BI", "Tableau", "Data Analysis"],
        ["Agile", "Scrum", "Project Management"],
        ["SEO", "Digital Marketing", "Content Writing"],
        ["React", "Redux", "JavaScript"],
        ["Angular", "TypeScript", "Frontend Development"],
        ["Java", "JavaFX", "Spring Boot"],
        ["Swift", "Objective-C", "iOS"],
        ["Unity", "Game Development", "C#"],
        ["Salesforce", "CRM", "Cloud Computing"],
        ["PHP", "Laravel", "Web Development"],
        ['Unreal Engine', 'Google Cloud', 'DevOps', 'Data Mining'],
        ['Kubernetes', 'NumPy', 'Django', 'TensorFlow', 'PostgreSQL', 'DevOps', 'Digital Marketing'],
        ['Unreal Engine', 'Tomcat', 'ML Ops', 'Postman', 'Ruby on Rails', 'C++', 'Data Visualization'],
        ['WebSockets', 'CI/CD', 'JSP', 'Data Science', 'SQLAlchemy', 'Kotlin'],
        ['Statistics', 'NumPy', 'Data Mining'],
        ['JUnit', 'Data Wrangling', 'FastAPI', 'Redux', 'Data Mining', 'React', 'Cloud Computing'],
        ['Scrapy', 'Game Development', 'HTML', 'Scikit-learn'],
        ['Data Mining', 'Scrapy', 'Hibernate', 'Deep Learning', 'iOS Development', 'Microservices', 'Spring Boot'],
        ['Angular', 'GraphQL', 'MySQL', 'JPA'],
        ['Data Wrangling', 'Ruby', 'Unreal Engine', 'Maven', 'Game Development', 'Postman', 'Scrapy'],
        ['Pandas', 'TensorFlow', 'Beautiful Soup', 'SQLAlchemy', 'Android Development', 'Figma'],
        ['C#', 'Swift', 'HTML', 'Keras'],
        ['Kafka', 'NumPy', 'Express', 'Figma'],
        ['Objective-C', 'Ruby on Rails', 'iOS Development', 'Figma', 'Jenkins', 'Responsive Design', 'C++'],
        ['Kotlin', 'Django', 'Python', 'Cucumber', 'Selenium', 'Web Scraping', 'WebSockets'],
        ['PHP', 'Data Visualization', 'JavaScript', 'Data Science', 'Unreal Engine', 'Unity', 'Web Scraping'],
        ['Vue.js', 'GraphQL', 'Microservices', 'C#'],
        ['Oracle', 'Swift', 'Power BI', 'Kafka', 'Web Scraping', 'APIs', 'Scrapy'],
        ['Hibernate', 'Responsive Design', 'Big Data', 'JUnit', 'Machine Learning', 'Flask', 'Azure'],
        ['NumPy', 'Git', 'Web Scraping'],
        ['R', 'JUnit', 'Unreal Engine', 'Ruby', 'Data Analysis', 'Git', 'Kubernetes'],
        ['Ruby on Rails', 'Kubernetes', 'Bootstrap', 'Ruby', 'Swift', 'Angular'],
        ['Azure', 'Pandas', 'UI/UX', 'Tomcat', 'SQL', 'NumPy'],
        ['JPA', 'Data Science', 'Scikit-learn', 'Servlets', 'Unreal Engine', 'Swift'],
        ['JavaScript', 'Web Scraping', 'NumPy', 'C++', 'APIs'],
        ['DevOps', 'JSP', 'Hadoop'],
        ['Kafka', 'iOS Development', 'Machine Learning', 'Game Development', 'API Integration', 'APIs', 'Express'],
        ['WebSockets', 'GitHub', 'CSS', 'Java'],
        ['Maven', 'Scrum', 'Spark', 'Unity', 'GitHub'],
        ['TensorFlow', 'MySQL', 'JSP', 'Web Scraping', 'Maven', 'Digital Marketing'],
        ['Data Visualization', 'Angular', 'Shopify', 'iOS Development', 'Ruby on Rails'],
        ['Java', 'Git', 'Machine Learning', 'Hadoop'],
        ['JavaScript', 'Data Analysis', 'Pandas', 'Shopify', 'HTML'],
        ['Deep Learning', 'Jenkins', 'Agile', 'API Integration', 'JSP', 'R'],
        ['NumPy', 'Terraform', 'Cloud Computing', 'Data Visualization', 'Power BI', 'Responsive Design', 'APIs'],
        ['JSP', 'Postman', 'Scikit-learn', 'AWS', 'APIs', 'SQLAlchemy', 'Statistics'],
        ['Jenkins', 'NumPy', 'TensorFlow', 'Hibernate', 'UI/UX', 'JPA'],
        ['Game Development', 'Web Scraping', 'REST API', 'Deep Learning', 'Cloud Computing', 'PHP'],
        ['Data Science', 'WebSockets', 'Azure', 'Spring Boot', 'Ruby', 'iOS Development'],
        ['Data Analysis', 'Java', 'FastAPI'],
        ['PostgreSQL', 'Power BI', 'Web Scraping', 'Express', 'Laravel', 'Scrum'],
        ['iOS Development', 'Hibernate', 'Kotlin', 'TypeScript', 'Data Analysis', 'C++'],
        ['ML Ops', 'APIs', 'API Integration', 'Figma', 'Python', 'SQL', 'Spring'],
        ['Deep Learning', 'APIs', 'Kubernetes'],
        ['MongoDB', 'Data Mining', 'Spring Boot', 'Express', 'Vue.js', 'Python', 'FastAPI'],
        ['Tableau', 'Docker', 'React', 'Selenium', 'Pandas', 'Node.js'],
        ['UI/UX', 'Cucumber', 'APIs', 'JavaScript', 'Java', 'Spring', 'Node.js'],
        ['Cucumber', 'Flask', 'Vue.js', 'C#'],
        ['React', 'FastAPI', 'Figma', 'DevOps'],
        ['Vue.js', 'Kubernetes', 'Jenkins', 'FastAPI', 'Selenium'],
        ['Kubernetes', 'Angular', 'Java', 'API Integration'],
        ['Flask', 'Java', 'JavaScript'],
        ['Node.js', 'Java', 'Data Analysis', 'Ruby']
    ],
    
    "Job Description Skills": [
        ["Python", "Machine Learning", "SQL", "Data Analysis"],
        ["Java", "Spring", "MySQL", "Hibernate"],
        ["HTML", "CSS", "JavaScript", "React"],
        ["Docker", "Kubernetes", "AWS", "DevOps"],
        ["Python", "Pandas", "NumPy", "Machine Learning"],
        ["Java", "Spring Boot", "REST", "Cloud"],
        ["HTML", "CSS", "Node.js", "Express"],
        ["Python", "Deep Learning", "TensorFlow", "Machine Learning"],
        ["JavaScript", "React", "Node.js", "Redux"],
        ["SQL", "Data Analysis", "Excel", "Power BI"],
        ["Python", "Web Scraping", "APIs", "Beautiful Soup"],
        ["Java", "Spring", "PostgreSQL", "Microservices"],
        ["JavaScript", "Angular", "HTML", "TypeScript"],
        ["C++", "Data Structures", "Algorithms", "Python"],
        ["DevOps", "CI/CD", "AWS", "Terraform"],
        ["Python", "Machine Learning", "Scikit-learn", "Data Analysis"],
        ["Java", "SQL", "Oracle", "Microservices"],
        ["HTML", "CSS", "Bootstrap", "JavaScript"],
        ["Python", "Statistics", "Machine Learning", "Data Visualization"],
        ["Java", "JUnit", "Maven", "SQL"],
        ["JavaScript", "API Integration", "Vue.js", "Frontend"],
        ["Python", "FastAPI", "Machine Learning", "Docker"],
        ["Java", "Spring", "AWS", "REST API"],
        ["HTML", "CSS", "React", "JavaScript"],
        ["Python", "Business Intelligence", "Tableau", "Data Visualization"],
        ["Java", "Eclipse", "MySQL", "JUnit"],
        ["Python", "Flask", "APIs", "SQLAlchemy"],
        ["JavaScript", "Node.js", "Express", "MongoDB"],
        ["Python", "NLP", "Machine Learning", "Text Analysis"],
        ["Java", "Hibernate", "SQL", "Struts"],
        ["HTML", "CSS", "JavaScript", "Responsive Design"],
        ["Python", "Big Data", "Spark", "Data Analysis"],
        ["Java", "Microservices", "Kafka", "Spring"],
        ["Python", "Pandas", "Data Cleaning", "Data Analysis"],
        ["JavaScript", "React", "API Development", "Frontend"],
        ["Java", "Java EE", "Web Development", "Tomcat"],
        ["Python", "Statistical Analysis", "Machine Learning", "Data Mining"],
        ["Java", "Oracle", "Spring MVC", "JDBC"],
        ["HTML", "CSS", "JavaScript", "Web Development"],
        ["Python", "NLP", "Machine Learning", "Data Analysis"],
        ["Java", "Microservices", "Cloud", "Golang"],
        ["JavaScript", "Frontend Development", "Vue.js", "Sass"],
        ["Python", "AWS", "ML Ops", "Deployment"],
        ["Java", "REST API", "MongoDB", "Spring Framework"],
        ["HTML", "CSS", "Web Design", "Bootstrap"],
        ["Python", "Data Visualization", "Seaborn", "Dash"],
        ["Java", "JSP", "Web Services", "MySQL"],
        ["JavaScript", "WebSockets", "Node.js", "Express"],
        ["Python", "Machine Learning", "Statistical Modeling", "R"],
        ["JavaScript", "Data Science", "Statistics"],
         ["Python", "Machine Learning", "SQL", "Data Analysis", "Java"],
    ["Java", "Spring", "MySQL", "Hibernate", "Node.js"],
    ["JavaScript", "HTML", "CSS", "Bootstrap", "React"],
    ["PHP", "MySQL", "WordPress", "JavaScript"],
        ["Bootstrap", "HTML", "CSS","Javascript"],
    ["C++", "Data Structures", "Algorithms", "Python"],
    ["Node.js", "Express", "MongoDB", "JavaScript"],
    ["Ruby", "Ruby on Rails", "SQL", "HTML"],
    ["C#", ".NET", "SQL Server", "Agile"],
    ["Swift", "iOS Development", "Objective-C"],
    ["Kotlin", "Android Development", "Java"],
    ["R", "Statistics", "Data Visualization"],
    ["TensorFlow", "Deep Learning", "Python"],
    ["Git", "GitHub", "Version Control", "Agile"],
    ["Docker", "Kubernetes", "DevOps"],
    ["Power BI", "Tableau", "Data Analysis"],
    ["Agile", "Scrum", "Project Management"],
    ["SEO", "Digital Marketing", "Content Writing"],
    ["React", "Redux", "JavaScript"],
    ["Angular", "TypeScript", "Frontend Development"],
    ["Java", "Spring Boot", "Microservices"],
    ["Swift", "Objective-C", "iOS"],
    ["Unity", "Game Development", "C#"],
    ["Salesforce", "CRM", "Cloud Computing"],
    ["PHP", "Laravel", "Web Development", "HTML"],
    ['Data Science', 'iOS Development', 'Shopify', 'Data Mining', 'Java'],
['Postman', 'Hibernate', 'Redux', 'React', 'Kubernetes', 'Figma', 'Servlets'],
['HTML', 'JavaScript', 'React','CSS'],
['Docker', 'Kubernetes', 'AWS','Containerization'],
['Python', 'Pandas', 'Data Visualization','TensoFlow'],
['Machine Learning', 'Spring Boot', 'Game Development', 'React', 'Kafka', 'C++', 'Python', 'Node.js'],
['Figma', 'Scikit-learn', 'Cucumber', 'ML Ops'],
['Scrum', 'Scrapy', 'PHP', 'Cloud Computing', 'Oracle', 'GitHub', 'Jenkins', 'Terraform'],
['Data Visualization', 'Unity', 'NumPy', 'MySQL'],
['CSS', 'Scikit-learn', 'Tableau', 'Django', 'Spark', 'Game Development'],
['JavaScript', 'CI/CD', 'Power BI', 'Agile', 'SQLAlchemy'],
['PostgreSQL', 'Beautiful Soup', 'Kafka', 'C#', 'JUnit'],
['Redux', 'Statistics', 'Kafka', 'Hadoop', 'Cloud Computing'],
['Angular', 'GraphQL', 'iOS Development', 'Big Data', 'Flask', 'FastAPI', 'REST API'],
['Data Mining', 'Postman', 'WebSockets', 'Objective-C', 'Selenium', 'MongoDB', 'Django', 'Big Data'],
['TensorFlow', 'TypeScript', 'JUnit', 'Data Science'],
['WordPress', 'Maven', 'Big Data', 'Unity', 'C++', 'TensorFlow', 'C#', 'Express'],
['Maven', 'Kafka', 'MySQL', 'Node.js', 'Data Analysis', 'iOS Development', 'Android Development'],
['PostgreSQL', 'Digital Marketing', 'Scikit-learn', 'Data Visualization', 'Flask', 'Docker', 'TypeScript'],
['NumPy', 'Cloud Computing', 'Laravel', 'WordPress', 'Angular', 'CI/CD'],
['SQLAlchemy', 'APIs', 'TypeScript', 'HTML', 'Statistical Modeling', 'Unreal Engine'],
['Ruby', 'Microservices', 'Flask', 'API Integration', 'APIs'],
['Azure', 'HTML', 'CSS', 'UI/UX', 'Java', 'React', 'Hadoop'],
['DevOps', 'Figma', 'JPA', 'Digital Marketing', 'Jira', 'Web Scraping'],
['Scrum', 'HTML', 'Angular', 'MongoDB', 'JavaScript', 'GitHub'],
['Kotlin', 'Spark', 'Tableau', 'Kubernetes', 'WordPress', 'JSP'],
['Machine Learning', 'Statistical Modeling', 'Redux', 'Shopify', 'PostgreSQL', 'Docker', 'AWS'],
['CSS', 'GraphQL', 'Statistical Modeling', 'NumPy', 'Google Cloud'],
['Hadoop', 'Spark', 'Tomcat', 'Figma', 'C++', 'Django', 'UI/UX'],
['Kafka', 'TensorFlow', 'C#', 'Ruby on Rails', 'Redux', 'Node.js', 'Agile', 'NumPy'],
['Agile', 'SQLAlchemy', 'C++', 'Statistics', 'Angular', 'Keras', 'API Integration', 'Servlets'],
['Hadoop', 'GitHub', 'Cloud Computing', 'Unity', 'FastAPI'],
['Web Scraping', 'C++', 'TypeScript', 'JavaScript', 'Angular'],
['Digital Marketing', 'APIs', 'TypeScript', 'API Integration', 'Data Mining', 'Unity'],
['Microservices', 'R', 'Laravel', 'Objective-C', 'NumPy'],
['Spark', 'DevOps', 'Responsive Design', 'AWS'],
['PHP', 'Flask', 'Agile', 'CSS', 'TensorFlow', 'Pandas', 'WordPress'],
['Spark', 'Scrum', 'Deep Learning', 'SEO', 'Oracle', 'Azure', 'React'],
['JPA', 'Statistics', 'C#', 'Figma', 'Game Development', 'Data Science', 'CSS', 'JavaScript'],
['Express', 'Java', 'JSP', 'CI/CD', 'Statistical Modeling'],
['JavaScript', 'SQLAlchemy', 'MySQL', 'Laravel', 'Postman', 'ML Ops'],
['GitHub', 'TypeScript', 'JUnit', 'Oracle', 'Machine Learning'],
['Google Cloud', 'Python', 'TypeScript', 'R', 'iOS Development'],
['TypeScript', 'Servlets', 'Data Visualization', 'Figma', 'DevOps', 'Spring Boot'],
['Ruby on Rails', 'Bootstrap', 'API Integration', 'Data Wrangling', 'Express', 'Agile', 'iOS Development'],
['Figma', 'Data Wrangling', 'Jira', 'Azure', 'Digital Marketing', 'Maven', 'R', 'Servlets'],
['Oracle', 'Spring Boot', 'Data Wrangling', 'Azure', 'JUnit', 'JavaScript'],
['UI/UX', 'ML Ops', 'NumPy', 'Objective-C'],
['AWS', 'Pandas', 'Flask', 'JUnit', 'TypeScript', 'TensorFlow', 'Spring Boot', 'Data Wrangling'],
['Flask', 'Scrum', 'DevOps', 'SQL', 'Oracle'],
['Unity', 'Power BI', 'SEO', 'DevOps', 'GitHub', 'HTML', 'Scrum', 'REST API'],
['React', 'Sass', 'Objective-C', 'Servlets', 'Tomcat', 'PHP', 'R'],
['Pandas', 'HTML', 'iOS Development', 'Maven', 'SQLAlchemy', 'WordPress'],
['Hibernate', 'Cloud Computing', 'Statistical Modeling', 'Swift', 'FastAPI', 'Keras'],
['NumPy', 'MySQL', 'Google Cloud', 'Data Mining', 'SQL', 'Oracle', 'SEO'],
['Terraform', 'WordPress', 'HTML', 'Web Scraping'],
['Ruby on Rails', 'Objective-C', 'Scrapy', 'APIs', 'Unreal Engine', 'Web Scraping', 'WordPress', 'Swift'],
['Python', 'SQLAlchemy', 'Maven', 'R', 'Flask'],
['Bootstrap', 'Hibernate', 'Laravel', 'Agile', 'SQLAlchemy', 'Game Development', 'Azure', 'Sass'],
['MySQL', 'Web Scraping', 'Kubernetes', 'C++', 'Azure', 'TypeScript', 'Java', 'UI/UX'],
['Ruby', 'Big Data', 'Kafka', 'Express', 'API Integration', 'JSP', 'Scikit-learn', 'GitHub'],
['Statistical Modeling', 'Node.js', 'JPA', 'Django', 'Tomcat', 'Terraform', 'FastAPI', 'Scikit-learn'],
['JUnit', 'PHP', 'APIs', 'C#', 'Redux'],
['Tomcat', 'Scikit-learn', 'Postman', 'TensorFlow'],
['FastAPI', 'AWS', 'Spring Boot', 'Express', 'Data Analysis', 'Tableau', 'React'],
['Data Science', 'TypeScript', 'Data Visualization', 'PHP'],
['SEO', 'Unity', 'Java', 'Terraform', 'Kafka'],
['APIs', 'Google Cloud', 'TypeScript', 'Azure', 'Agile', 'JavaScript', 'R', 'TensorFlow'],
['Scrapy', 'Sass', 'Python', 'Kubernetes', 'FastAPI'],
['JPA', 'Redux', 'UI/UX', 'Ruby', 'Postman', 'Docker'],
['Sass', 'HTML', 'Laravel', 'React', 'Data Wrangling'],
['Statistics', 'JavaScript', 'iOS Development', 'SQL', 'TensorFlow', 'Power BI'],
['HTML', 'Responsive Design', 'Ruby on Rails', 'Docker', 'Data Science', 'Bootstrap', 'JPA', 'Keras'],
['APIs', 'Objective-C', 'Pandas', 'WordPress', 'JSP', 'Scrapy', 'Cucumber', 'Data Wrangling'],
['React', 'GraphQL', 'Power BI', 'Unreal Engine', 'Hibernate'],
['SEO', 'Keras', 'Unreal Engine', 'Web Scraping', 'Unity', 'Jenkins', 'WordPress'],
['Jenkins', 'Machine Learning', 'REST API', 'Statistics', 'C++'],
['REST API', 'Tomcat', 'TensorFlow', 'HTML', 'APIs', 'UI/UX'],
['Flask', 'Scrapy', 'Game Development', 'Data Mining', 'Keras', 'CI/CD'],
['Machine Learning', 'JavaScript', 'Responsive Design', 'iOS Development', 'Kafka', 'Deep Learning', 'Maven'],
['Git', 'Spring Boot', 'Beautiful Soup', 'Scrapy'],
['C#', 'MySQL', 'Node.js', 'SEO', 'Beautiful Soup', 'Statistics'],
['SEO', 'SQLAlchemy', 'Scikit-learn', 'Scrum', 'Deep Learning', 'Scrapy'],
['Game Development', 'Django', 'Jenkins', 'Data Wrangling', 'HTML', 'Maven', 'Microservices', 'Servlets'],
['UI/UX', 'Spring Boot', 'Android Development', 'Oracle', 'Jira', 'SQL', 'Postman'],
['Unity', 'NumPy', 'AWS', 'PHP', 'REST API', 'API Integration', 'Django', 'Beautiful Soup'],
['Jenkins', 'Figma', 'Machine Learning', 'Power BI', 'Java', 'C#', 'Deep Learning', 'Objective-C'],
['Tableau', 'Java', 'FastAPI', 'Digital Marketing', 'Machine Learning', 'Keras', 'Google Cloud', 'WordPress'],
['Jira', 'PostgreSQL', 'CI/CD', 'PHP', 'Jenkins', 'Django', 'APIs', 'Beautiful Soup'],
['Deep Learning', 'Data Analysis', 'Keras', 'Django', 'FastAPI', 'JavaScript', 'Statistical Modeling'],
['Figma', 'Machine Learning', 'Scrapy', 'REST API', 'Flask', 'C++'],
['WebSockets', 'HTML', 'Cloud Computing', 'Power BI'],
['Scrum', 'JavaScript', 'FastAPI', 'Spring Boot', 'Git'],
['Jira', 'API Integration', 'Java', 'Cloud Computing'],
['Machine Learning', 'MySQL', 'Pandas', 'Selenium', 'JavaScript', 'Unity'],
['Postman', 'Java', 'Agile', 'Game Development', 'Data Wrangling', 'API Integration', 'Flask', 'Jenkins'],
['Tableau', 'CI/CD', 'Power BI', 'Google Cloud'],
['Machine Learning', 'FastAPI', 'Kubernetes', 'PostgreSQL', 'C#', 'HTML'],
['Power BI', 'Deep Learning', 'Jenkins', 'NumPy', 'Flask', 'FastAPI', 'C++', 'PHP'],
['FastAPI', 'API Integration', 'Java', 'JavaScript', 'Unity'],
['Kubernetes', 'API Integration', 'Data Mining', 'Machine Learning', 'JSP'],
['Data Analysis', 'Flask', 'JSP', 'Java', 'JavaScript'],
['Pandas', 'Beautiful Soup', 'Java', 'Google Cloud', 'FastAPI'],
['Postman', 'Cucumber', 'Game Development', 'Pandas', 'Objective-C'],
['Game Development', 'Spring Boot', 'PostgreSQL', 'Data Analysis', 'TensorFlow', 'Scrapy', 'Figma', 'Ruby'],
['Jira', 'Deep Learning', 'Unity', 'CI/CD', 'Django', 'JavaScript'],
['Java', 'Power BI', 'Game Development', 'Hadoop'],
['Flask', 'JavaScript', 'HTML', 'Node.js', 'Spring Boot'],
['Cucumber', 'Java', 'Power BI', 'GitHub'],
['Game Development', 'Unity', 'Figma', 'Cucumber'],
['FastAPI', 'Machine Learning', 'Java', 'Power BI', 'Data Analysis'],
['Pandas', 'Data Mining', 'Java', 'Git'],
['JavaScript', 'Machine Learning', 'Deep Learning', 'Ruby', 'Cloud Computing', 'PostgreSQL', 'Flask'],
['Kubernetes', 'Django', 'FastAPI', 'TensorFlow', 'Oracle', 'Game Development'],
['Data Wrangling', 'Data Analysis', 'Machine Learning', 'Java', 'FastAPI'],
['Power BI', 'Data Wrangling', 'Deep Learning', 'Data Science'],
['Beautiful Soup', 'API Integration', 'Flask', 'Java', 'Machine Learning'],
['JavaScript', 'C#', 'Node.js', 'WebSockets'],
['Ruby on Rails', 'React', 'Java', 'Deep Learning', 'Game Development'],
['Python', 'HTML', 'JavaScript', 'Kubernetes', 'PostgreSQL'],
['Java', 'Data Wrangling', 'Git', 'Cloud Computing', 'Selenium'],
['Java', 'Node.js', 'API Integration', 'FastAPI', 'Machine Learning'],
['Deep Learning', 'Scrapy', 'Python', 'Flask'],
['WebSockets', 'Power BI', 'JavaScript', 'PHP', 'Data Science'],
['Selenium', 'Postman', 'Beautiful Soup', 'JavaScript', 'Spring Boot', 'iOS Development'],
['Machine Learning', 'FastAPI', 'Java', 'Django', 'PostgreSQL'],
['Flask', 'Java', 'JavaScript', 'Unity', 'WebSockets'],
['Node.js', 'Java', 'Data Analysis', 'Ruby']
    ],
}

# Create DataFrame
df = pd.DataFrame(data)

# Enhanced Recommendations mapping
recommendations_dict = {
    "Python": "Practice Python coding exercises to improve your programming skills.",
    "Machine Learning": "Consider enrolling in an online machine learning course to grasp key concepts and techniques.",
    "SQL": "Take an SQL course to enhance your database skills and query efficiency.",
    "Data Analysis": "Explore data analysis projects using tools like Pandas and NumPy for hands-on experience.",
    "Java": "Dive deeper into Java by working on real-world projects or contributing to open-source.",
    "Spring": "Familiarize yourself with Spring framework tutorials to improve your Java backend skills.",
    "MySQL": "Consider advanced MySQL courses to learn about performance tuning and database design.",
    "Hibernate": "Explore Hibernate tutorials to enhance your Java framework knowledge.",
    "HTML": "Practice building responsive web pages using HTML5 and CSS.",
    "CSS": "Learn CSS frameworks like Bootstrap to speed up your styling process.",
    "JavaScript": "Work on JavaScript projects to strengthen your frontend development skills.",
    "React": "Build a React application to understand component-based architecture better.",
    "Docker": "Familiarize yourself with Docker for containerization of applications.",
    "Kubernetes": "Learn Kubernetes basics to manage containerized applications efficiently.",
    "AWS": "Consider AWS certification to enhance your cloud computing skills.",
    "DevOps": "Explore DevOps tools and practices to streamline software development and deployment.",
    "Pandas": "Work on data manipulation tasks with Pandas to solidify your data handling skills.",
    "NumPy": "Utilize NumPy for numerical computations in Python to improve performance.",
    "Deep Learning": "Enroll in a deep learning specialization to dive into advanced neural networks.",
    "TensorFlow": "Practice building models in TensorFlow to understand deep learning workflows.",
    "Data Visualization": "Use libraries like Matplotlib or Seaborn for visualizing data insights.",
    "Power BI": "Learn Power BI to create interactive dashboards and reports.",
    "Flask": "Build web applications with Flask to understand lightweight web frameworks.",
    "APIs": "Explore RESTful API design to integrate different software applications.",
    "Beautiful Soup": "Practice web scraping with Beautiful Soup to gather data from websites.",
    "Data Mining": "Engage in data mining projects to uncover patterns and insights from datasets.",
    "Statistics": "Brush up on statistics to strengthen your analytical skills in data science.",
    "GraphQL": "Explore GraphQL to understand modern API development and data fetching.",
    "CI/CD": "Learn CI/CD practices to automate testing and deployment processes.",
    "Machine Learning": "Consider courses in Scikit-learn to enhance your machine learning skillset.",
    "Digital Marketing": "Familiarize yourself with digital marketing strategies and analytics tools.",
    "SEO": "Learn SEO best practices to improve website visibility and search engine ranking.",
    "Game Development": "Try game development tutorials using Unity to bring your ideas to life.",
    "Ruby": "Explore Ruby on Rails for web application development.",
    "PHP": "Practice building applications using PHP for server-side scripting.",
    "iOS Development": "Learn Swift and Xcode to develop iOS applications.",
    "Android Development": "Dive into Kotlin for creating Android apps and understand the Android ecosystem.",
    "Git": "Familiarize yourself with Git for version control and collaboration on projects.",
    "Jenkins": "Explore Jenkins for continuous integration and delivery pipelines.",
    "Scrum": "Consider certifications in Scrum to understand agile methodologies.",
    "Figma": "Use Figma to design user interfaces and enhance your UI/UX skills.",
    "Tableau": "Practice building dashboards in Tableau for effective data visualization.",
    "Unity": "Engage in Unity tutorials for game design and development.",
    "R": "Explore R for statistical analysis and data visualization.",
    "Kotlin": "Familiarize yourself with Kotlin for modern Android development.",
    "C++": "Practice C++ programming through projects to strengthen your software development skills.",
    "Flask": "Build projects using Flask to understand web development with Python.",
    "Postman": "Use Postman for API testing and documentation.",
    "Agile": "Engage in agile project management courses to improve team collaboration.",
    "JPA": "Explore Java Persistence API (JPA) to manage relational data in Java applications.",
    "TypeScript": "Learn TypeScript to enhance your JavaScript applications with type safety.",
    "REST API": "Develop RESTful APIs to understand client-server communication."
}


# Function to calculate match score, missing skills, and recommendations
def calculate_match_score_and_missing(resume_skills, job_skills):
    resume_set = set(resume_skills)
    job_set = set(job_skills)
    
    common_skills = resume_set.intersection(job_set)
    missing_skills = job_set - resume_set  # Skills in job description but not in resume
    total_skills = resume_set.union(job_set)
    
    if not total_skills:  # Prevent division by zero
        match_score = 0.0
    else:
        match_score = len(common_skills) / len(total_skills)

    # Generate recommendations based on missing skills
    recommendations = []
    for skill in missing_skills:
        if skill in recommendations_dict:
            recommendations.append(recommendations_dict[skill])
        else:
            # Generic recommendation for missing skills not in the dictionary
            recommendations.append(f"Consider exploring resources to learn {skill}.")

    return match_score, list(missing_skills), recommendations

# Apply the function to calculate match score, missing skills, and recommendations
df[['Match Score', 'Missing Skills', 'Recommendations']] = df.apply(
    lambda row: calculate_match_score_and_missing(row['Resume Skills'], row['Job Description Skills']), axis=1, result_type='expand'
)

# Save DataFrame to CSV
csv_file_path = 'C:/Users/Aswathy/OneDrive/Desktop/mini_proj/dataset1.csv'
df.to_csv(csv_file_path, index=False)

# %%
import pandas as pd

# Generate sample data for the dataset
data = {
    "Resume Skills": [
        ["Python", "Machine Learning", "Data Analysis", "SQL"],
        ["Java", "Spring", "Hibernate", "MySQL"],
        ["HTML", "CSS", "JavaScript", "React"],
        ["Docker", "Kubernetes", "AWS", "DevOps"],
        ["Python", "Pandas", "NumPy", "Data Visualization"],
        ["Java", "REST", "Microservices", "Cloud"],
        ["HTML", "CSS", "Node.js", "Express"],
        ["Python", "Deep Learning", "TensorFlow", "Keras"],
        ["JavaScript", "React", "Redux", "Node.js"],
        ["SQL", "Data Analysis", "Power BI", "Excel"],
        ["Python", "Scrapy", "Beautiful Soup", "APIs"],
        ["Java", "Spring Boot", "JPA", "PostgreSQL"],
        ["JavaScript", "Angular", "TypeScript", "HTML"],
        ["C++", "Algorithms", "Data Structures", "Python"],
        ["DevOps", "CI/CD", "Jenkins", "Terraform"],
        ["Python", "Machine Learning", "Scikit-learn", "Pandas"],
        ["Java", "Oracle", "SQL", "Microservices"],
        ["HTML", "CSS", "Bootstrap", "JavaScript"],
        ["Python", "Data Science", "Statistics", "Matplotlib"],
        ["Java", "JavaFX", "Maven", "JUnit"],
        ["JavaScript", "Vue.js", "Nuxt.js", "API Integration"],
        ["Python", "FastAPI", "Machine Learning", "Docker"],
        ["Java", "REST API", "Spring Cloud", "AWS"],
        ["HTML", "CSS", "React", "Redux"],
        ["Python", "Tableau", "Data Visualization", "Business Intelligence"],
        ["Java", "Eclipse", "JUnit", "MySQL"],
        ["Python", "Flask", "APIs", "SQLAlchemy"],
        ["JavaScript", "Node.js", "Express", "MongoDB"],
        ["Python", "NLP", "SpaCy", "Text Analysis"],
        ["Java", "Struts", "Hibernate", "SQL"],
        ["HTML", "CSS", "JavaScript", "Frontend Development"],
        ["Python", "Big Data", "Spark", "Hadoop"],
        ["Java", "Kafka", "Microservices", "Spring"],
        ["Python", "Data Cleaning", "Pandas", "NumPy"],
        ["JavaScript", "React", "API Development", "Frontend"],
        ["Java", "Web Development", "Java EE", "Tomcat"],
        ["Python", "Statistical Analysis", "Data Mining", "Machine Learning"],
        ["Java", "Spring MVC", "JDBC", "Oracle"],
        ["HTML", "CSS", "JavaScript", "Responsive Design"],
        ["Python", "Data Wrangling", "Pandas", "NLP"],
        ["Java", "Golang", "Cloud", "Microservices"],
        ["JavaScript", "Sass", "Vue.js", "Frontend Development"],
        ["Python", "ML Ops", "Deployment", "AWS"],
        ["Java", "Spring Framework", "MongoDB", "REST API"],
        ["HTML", "CSS", "Bootstrap", "Web Design"],
        ["Python", "Data Visualization", "Seaborn", "Dash"],
        ["Java", "JSP", "Servlets", "MySQL"],
        ["JavaScript", "Express", "WebSockets", "Node.js"],
        ["Python", "Statistical Modeling", "R", "Machine Learning"],
        ["JavaScript", "Machine Learning", "Statistics"]
    ],
    "Job Description Skills": [
        ["Python", "Machine Learning", "SQL", "Data Analysis"],
        ["Java", "Spring", "MySQL", "Hibernate"],
        ["HTML", "CSS", "JavaScript", "React"],
        ["Docker", "Kubernetes", "AWS", "DevOps"],
        ["Python", "Pandas", "NumPy", "Machine Learning"],
        ["Java", "Spring Boot", "REST", "Cloud"],
        ["HTML", "CSS", "Node.js", "Express"],
        ["Python", "Deep Learning", "TensorFlow", "Machine Learning"],
        ["JavaScript", "React", "Node.js", "Redux"],
        ["SQL", "Data Analysis", "Excel", "Power BI"],
        ["Python", "Web Scraping", "APIs", "Beautiful Soup"],
        ["Java", "Spring", "PostgreSQL", "Microservices"],
        ["JavaScript", "Angular", "HTML", "TypeScript"],
        ["C++", "Data Structures", "Algorithms", "Python"],
        ["DevOps", "CI/CD", "AWS", "Terraform"],
        ["Python", "Machine Learning", "Scikit-learn", "Data Analysis"],
        ["Java", "SQL", "Oracle", "Microservices"],
        ["HTML", "CSS", "Bootstrap", "JavaScript"],
        ["Python", "Statistics", "Machine Learning", "Data Visualization"],
        ["Java", "JUnit", "Maven", "SQL"],
        ["JavaScript", "API Integration", "Vue.js", "Frontend"],
        ["Python", "FastAPI", "Machine Learning", "Docker"],
        ["Java", "Spring", "AWS", "REST API"],
        ["HTML", "CSS", "React", "JavaScript"],
        ["Python", "Business Intelligence", "Tableau", "Data Visualization"],
        ["Java", "Eclipse", "MySQL", "JUnit"],
        ["Python", "Flask", "APIs", "SQLAlchemy"],
        ["JavaScript", "Node.js", "Express", "MongoDB"],
        ["Python", "NLP", "Machine Learning", "Text Analysis"],
        ["Java", "Hibernate", "SQL", "Struts"],
        ["HTML", "CSS", "JavaScript", "Responsive Design"],
        ["Python", "Big Data", "Spark", "Data Analysis"],
        ["Java", "Microservices", "Kafka", "Spring"],
        ["Python", "Pandas", "Data Cleaning", "Data Analysis"],
        ["JavaScript", "React", "API Development", "Frontend"],
        ["Java", "Java EE", "Web Development", "Tomcat"],
        ["Python", "Statistical Analysis", "Machine Learning", "Data Mining"],
        ["Java", "Oracle", "Spring MVC", "JDBC"],
        ["HTML", "CSS", "JavaScript", "Web Development"],
        ["Python", "NLP", "Machine Learning", "Data Analysis"],
        ["Java", "Microservices", "Cloud", "Golang"],
        ["JavaScript", "Frontend Development", "Vue.js", "Sass"],
        ["Python", "AWS", "ML Ops", "Deployment"],
        ["Java", "REST API", "MongoDB", "Spring Framework"],
        ["HTML", "CSS", "Web Design", "Bootstrap"],
        ["Python", "Data Visualization", "Seaborn", "Dash"],
        ["Java", "JSP", "Web Services", "MySQL"],
        ["JavaScript", "WebSockets", "Node.js", "Express"],
        ["Python", "Machine Learning", "Statistical Modeling", "R"],
        ["JavaScript", "Data Science", "Statistics"]
    ],
    "Match Score": [0.75, 0.67, 0.75, 0.75, 0.75, 0.67, 0.75, 0.67, 0.75, 0.75,
                    0.75, 0.67, 0.75, 0.75, 0.75, 0.67, 0.75, 0.75, 0.75, 0.75,
                    0.67, 0.75, 0.75, 0.75, 0.67, 0.75, 0.75, 0.67, 0.75, 0.75,
                    0.75, 0.75, 0.67, 0.75, 0.75, 0.75, 0.75, 0.75, 0.67, 0.75,
                    0.75, 0.67, 0.75, 0.75, 0.75, 0.67, 0.75, 0.75, 0.75, 0.75],
    "Missing Skills": [
        ["SQL"], ["Hibernate"], ["Node.js"], ["DevOps"], ["Machine Learning"],
        ["Cloud"], ["TypeScript"], ["Deep Learning"], ["Node.js"], ["Power BI"],
        ["Web Scraping"], ["Microservices"], ["TypeScript"], ["C++", "Python"],
        ["Terraform"], ["Machine Learning"], ["Microservices"], ["Bootstrap"],
        ["Data Visualization"], ["JUnit"], ["Frontend"], ["FastAPI"],
        ["Java"], ["JavaScript"], ["Python"], ["Java"], ["Flask"],
        ["MongoDB"], ["Machine Learning"], ["SQL", "Struts"], ["HTML"],
        ["Big Data"], ["Kafka"], ["Data Analysis"], ["JavaScript"],
        ["Java EE"], ["Data Mining"], ["Java"], ["Spring MVC"],
        ["Web Development"], ["NLP"], ["Golang"], ["Sass"],
        ["Deployment"], ["Spring Framework"], ["Bootstrap"], ["Dash"],
        ["MySQL"], ["Frontend Frameworks"],
        ["Data Science"]
    ],
    "Recommendations": [
        "Consider taking an SQL course to improve your database skills.",
        "Explore Hibernate tutorials to enhance your Java framework knowledge.",
        "Familiarize yourself with Node.js to strengthen your full-stack capabilities.",
        "Gain practical experience in DevOps tools to meet job requirements.",
        "Enhance your skills in Machine Learning through online courses.",
        "Get hands-on experience with cloud platforms to meet industry demands.",
        "Learn TypeScript for better development practices in modern JavaScript.",
        "Study Deep Learning frameworks to advance your AI knowledge.",
        "Strengthen your Node.js skills for backend development opportunities.",
        "Explore Power BI to enhance your data visualization capabilities.",
        "Practice web scraping techniques to gain practical insights.",
        "Deepen your understanding of Microservices architecture.",
        "Learn TypeScript for better integration in JavaScript projects.",
        "Brush up on C++ algorithms for improved programming skills.",
        "Familiarize yourself with Terraform for better DevOps practices.",
        "Strengthen your machine learning skills through practical projects.",
        "Explore Microservices concepts for better software architecture.",
        "Learn Bootstrap to improve responsive web design skills.",
        "Focus on data visualization tools for effective communication of data.",
        "Get comfortable with JUnit for effective unit testing in Java.",
        "Expand your frontend skills by learning more JavaScript frameworks.",
        "Take FastAPI tutorials to enhance your Python backend skills.",
        "Consider learning Java to solidify your programming foundation.",
        "Enhance your JavaScript skills through more hands-on projects.",
        "Practice Python for data-related projects to build expertise.",
        "Study advanced Java concepts to improve your programming knowledge.",
        "Work on Flask projects to enhance your Python web development skills.",
        "Learn about MongoDB for better understanding of NoSQL databases.",
        "Deepen your knowledge of machine learning for data-driven projects.",
        "Familiarize yourself with SQL and Struts for better Java programming.",
        "Enhance your HTML/CSS skills for improved frontend development.",
        "Gain experience in Big Data technologies for scalable applications.",
        "Learn Kafka for better understanding of event-driven architectures.",
        "Practice data analysis techniques for data-centric roles.",
        "Expand your knowledge of JavaScript frameworks for modern development.",
        "Strengthen your Java EE knowledge for enterprise applications.",
        "Learn data mining techniques for better insights from data.",
        "Enhance your Java knowledge to tackle complex programming challenges.",
        "Focus on MVC architecture for better understanding of web applications.",
        "Work on web development projects to enhance your portfolio.",
        "Explore NLP libraries for better text processing skills.",
        "Get familiar with Golang for performance-oriented programming.",
        "Learn Sass for better CSS organization and structure.",
        "Get practical experience in deployment strategies for cloud applications.",
        "Deepen your knowledge of Spring Framework for better Java development.",
        "Work on Bootstrap projects to enhance your responsive design skills.",
        "Learn Dash to create interactive web applications.",
        "Practice MySQL for better understanding of relational databases.",
        "Work on frontend frameworks to improve user interface development.",
        "Focus on data science projects to build a strong analytical portfolio."
    ]
}
print(len(data["Resume Skills"]))
print(len(data["Job Description Skills"]))
print(len(data["Match Score"]))
print(len(data["Missing Skills"]))
print(len(data["Recommendations"]))
# Create DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
csv_file_path = 'C:/Users/Aswathy/OneDrive/Desktop/mini_proj/dataset.csv'
df.to_csv(csv_file_path, index=False)

csv_file_path
# Out:
# 50
# 50
# 50
# 50
# 50
# 'C:/Users/Aswathy/OneDrive/Desktop/mini_proj/dataset.csv'

# %%
import pandas as pd

# Generate sample data for the dataset
data = {
    "Resume Skills": [
        ["Python", "Machine Learning", "Data Analysis", "SQL"],
        ["Java", "Spring", "Hibernate", "MySQL"],
        ["HTML", "CSS", "JavaScript", "React"],
        ["Docker", "Kubernetes", "AWS", "DevOps"],
        ["Python", "Pandas", "NumPy", "Data Visualization"],
        ["Java", "REST", "Microservices", "Cloud"],
        ["HTML", "CSS", "Node.js", "Express"],
        ["Python", "Deep Learning", "TensorFlow", "Keras"],
        ["JavaScript", "React", "Redux", "Node.js"],
        ["SQL", "Data Analysis", "Power BI", "Excel"],
        ["Python", "Scrapy", "Beautiful Soup", "APIs"],
        ["Java", "Spring Boot", "JPA", "PostgreSQL"],
        ["JavaScript", "Angular", "TypeScript", "HTML"],
        ["C++", "Algorithms", "Data Structures", "Python"],
        ["DevOps", "CI/CD", "Jenkins", "Terraform"],
        ["Python", "Machine Learning", "Scikit-learn", "Pandas"],
        ["Java", "Oracle", "SQL", "Microservices"],
        ["HTML", "CSS", "Bootstrap", "JavaScript"],
        ["Python", "Data Science", "Statistics", "Matplotlib"],
        ["Java", "JavaFX", "Maven", "JUnit"],
        ["JavaScript", "Vue.js", "Nuxt.js", "API Integration"],
        ["Python", "FastAPI", "Machine Learning", "Docker"],
        ["Java", "REST API", "Spring Cloud", "AWS"],
        ["HTML", "CSS", "React", "Redux"],
        ["Python", "Tableau", "Data Visualization", "Business Intelligence"],
        ["Java", "Eclipse", "JUnit", "MySQL"],
        ["Python", "Flask", "APIs", "SQLAlchemy"],
        ["JavaScript", "Node.js", "Express", "MongoDB"],
        ["Python", "NLP", "SpaCy", "Text Analysis"],
        ["Java", "Struts", "Hibernate", "SQL"],
        ["HTML", "CSS", "JavaScript", "Frontend Development"],
        ["Python", "Big Data", "Spark", "Hadoop"],
        ["Java", "Kafka", "Microservices", "Spring"],
        ["Python", "Data Cleaning", "Pandas", "NumPy"],
        ["JavaScript", "React", "API Development", "Frontend"],
        ["Java", "Web Development", "Java EE", "Tomcat"],
        ["Python", "Statistical Analysis", "Data Mining", "Machine Learning"],
        ["Java", "Spring MVC", "JDBC", "Oracle"],
        ["HTML", "CSS", "JavaScript", "Responsive Design"],
        ["Python", "Data Wrangling", "Pandas", "NLP"],
        ["Java", "Golang", "Cloud", "Microservices"],
        ["JavaScript", "Sass", "Vue.js", "Frontend Development"],
        ["Python", "ML Ops", "Deployment", "AWS"],
        ["Java", "Spring Framework", "MongoDB", "REST API"],
        ["HTML", "CSS", "Bootstrap", "Web Design"],
        ["Python", "Data Visualization", "Seaborn", "Dash"],
        ["Java", "JSP", "Servlets", "MySQL"],
        ["JavaScript", "Express", "WebSockets", "Node.js"],
        ["Python", "Statistical Modeling", "R", "Machine Learning"],
        ["JavaScript", "Machine Learning", "Statistics"]
    ],
    "Job Description Skills": [
        ["Python", "Machine Learning", "SQL", "Data Analysis"],
        ["Java", "Spring", "MySQL", "Hibernate"],
        ["HTML", "CSS", "JavaScript", "React"],
        ["Docker", "Kubernetes", "AWS", "DevOps"],
        ["Python", "Pandas", "NumPy", "Machine Learning"],
        ["Java", "Spring Boot", "REST", "Cloud"],
        ["HTML", "CSS", "Node.js", "Express"],
        ["Python", "Deep Learning", "TensorFlow", "Machine Learning"],
        ["JavaScript", "React", "Node.js", "Redux"],
        ["SQL", "Data Analysis", "Excel", "Power BI"],
        ["Python", "Web Scraping", "APIs", "Beautiful Soup"],
        ["Java", "Spring", "PostgreSQL", "Microservices"],
        ["JavaScript", "Angular", "HTML", "TypeScript"],
        ["C++", "Data Structures", "Algorithms", "Python"],
        ["DevOps", "CI/CD", "AWS", "Terraform"],
        ["Python", "Machine Learning", "Scikit-learn", "Data Analysis"],
        ["Java", "SQL", "Oracle", "Microservices"],
        ["HTML", "CSS", "Bootstrap", "JavaScript"],
        ["Python", "Statistics", "Machine Learning", "Data Visualization"],
        ["Java", "JUnit", "Maven", "SQL"],
        ["JavaScript", "API Integration", "Vue.js", "Frontend"],
        ["Python", "FastAPI", "Machine Learning", "Docker"],
        ["Java", "Spring", "AWS", "REST API"],
        ["HTML", "CSS", "React", "JavaScript"],
        ["Python", "Business Intelligence", "Tableau", "Data Visualization"],
        ["Java", "Eclipse", "MySQL", "JUnit"],
        ["Python", "Flask", "APIs", "SQLAlchemy"],
        ["JavaScript", "Node.js", "Express", "MongoDB"],
        ["Python", "NLP", "Machine Learning", "Text Analysis"],
        ["Java", "Hibernate", "SQL", "Struts"],
        ["HTML", "CSS", "JavaScript", "Responsive Design"],
        ["Python", "Big Data", "Spark", "Data Analysis"],
        ["Java", "Microservices", "Kafka", "Spring"],
        ["Python", "Pandas", "Data Cleaning", "Data Analysis"],
        ["JavaScript", "React", "API Development", "Frontend"],
        ["Java", "Java EE", "Web Development", "Tomcat"],
        ["Python", "Statistical Analysis", "Machine Learning", "Data Mining"],
        ["Java", "Oracle", "Spring MVC", "JDBC"],
        ["HTML", "CSS", "JavaScript", "Web Development"],
        ["Python", "NLP", "Machine Learning", "Data Analysis"],
        ["Java", "Microservices", "Cloud", "Golang"],
        ["JavaScript", "Frontend Development", "Vue.js", "Sass"],
        ["Python", "AWS", "ML Ops", "Deployment"],
        ["Java", "REST API", "MongoDB", "Spring Framework"],
        ["HTML", "CSS", "Web Design", "Bootstrap"],
        ["Python", "Data Visualization", "Seaborn", "Dash"],
        ["Java", "JSP", "Web Services", "MySQL"],
        ["JavaScript", "WebSockets", "Node.js", "Express"],
        ["Python", "Machine Learning", "Statistical Modeling", "R"],
        ["JavaScript", "Data Science", "Statistics"]
    ],
    "Recommendations": [
        "Consider taking an SQL course to improve your database skills.",
        "Explore Hibernate tutorials to enhance your Java framework knowledge.",
        "Familiarize yourself with Node.js to strengthen your full-stack capabilities.",
        "Gain practical experience in DevOps tools to meet job requirements.",
        "Enhance your skills in Machine Learning through online courses.",
        "Get hands-on experience with cloud platforms to meet industry demands.",
        "Learn TypeScript for better development practices in modern JavaScript.",
        "Study Deep Learning frameworks to advance your AI knowledge.",
        "Strengthen your Node.js skills for backend development opportunities.",
        "Explore Power BI to enhance your data visualization capabilities.",
        "Practice web scraping techniques to gain practical insights.",
        "Deepen your understanding of Microservices architecture.",
        "Learn TypeScript for better integration in JavaScript projects.",
        "Brush up on C++ algorithms for improved programming skills.",
        "Familiarize yourself with Terraform for better DevOps practices.",
        "Strengthen your machine learning skills through practical projects.",
        "Explore Microservices concepts for better software architecture.",
        "Learn Bootstrap to improve responsive web design skills.",
        "Focus on data visualization tools for effective communication of data.",
        "Get comfortable with JUnit for effective unit testing in Java.",
        "Expand your frontend skills by learning more JavaScript frameworks.",
        "Take FastAPI tutorials to enhance your Python backend skills.",
        "Consider learning Java to solidify your programming foundation.",
        "Enhance your JavaScript skills through more hands-on projects.",
        "Practice Python for data-related projects to build expertise.",
        "Study advanced Java concepts to improve your programming knowledge.",
        "Work on Flask projects to enhance your Python web development skills.",
        "Learn about MongoDB for better understanding of NoSQL databases.",
        "Deepen your knowledge of machine learning for data-driven projects.",
        "Familiarize yourself with SQL and Struts for better Java programming.",
        "Enhance your HTML/CSS skills for improved frontend development.",
        "Gain experience in Big Data technologies for scalable applications.",
        "Learn Kafka for better understanding of event-driven architectures.",
        "Practice data analysis techniques for data-centric roles.",
        "Expand your knowledge of JavaScript frameworks for modern development.",
        "Strengthen your Java EE knowledge for enterprise applications.",
        "Learn data mining techniques for better insights from data.",
        "Enhance your Java knowledge to tackle complex programming challenges.",
        "Focus on MVC architecture for better understanding of web applications.",
        "Work on web development projects to enhance your portfolio.",
        "Explore NLP libraries for better text processing skills.",
        "Get familiar with Golang for performance-oriented programming.",
        "Learn Sass for better CSS organization and structure.",
        "Get practical experience in deployment strategies for cloud applications.",
        "Deepen your knowledge of Spring Framework for better Java development.",
        "Work on Bootstrap projects to enhance your responsive design skills.",
        "Learn Dash to create interactive web applications.",
        "Practice MySQL for better understanding of relational databases.",
        "Work on frontend frameworks to improve user interface development.",
        "Focus on data science projects to build a strong analytical portfolio."
    ]
}
print(len(data["Resume Skills"]))
print(len(data["Job Description Skills"]))

print(len(data["Recommendations"]))
# Create DataFrame
df = pd.DataFrame(data)

# Function to calculate match score
def calculate_match_score(resume_skills, job_skills):
    resume_set = set(resume_skills)
    job_set = set(job_skills)
    common_skills = resume_set.intersection(job_set)
    total_skills = resume_set.union(job_set)
    
    if not total_skills:  # Prevent division by zero
        return 0.0
    return len(common_skills) / len(total_skills)

# Calculate the matching score and replace the existing values
df['Match Score'] = df.apply(lambda row: calculate_match_score(row['Resume Skills'], row['Job Description Skills']), axis=1)

# Save DataFrame to CSV
csv_file_path = 'C:/Users/Aswathy/OneDrive/Desktop/mini_proj/dataaset.csv'
df.to_csv(csv_file_path, index=False)

# Check the updated DataFrame



print(df)
# Out:
# 50
# 50
# 50
#                                         Resume Skills  \
# 0      [Python, Machine Learning, Data Analysis, SQL]
# 1                    [Java, Spring, Hibernate, MySQL]
# 2                      [HTML, CSS, JavaScript, React]
# 3                   [Docker, Kubernetes, AWS, DevOps]
# 4         [Python, Pandas, NumPy, Data Visualization]
# 5                  [Java, REST, Microservices, Cloud]
# 6                       [HTML, CSS, Node.js, Express]
# 7          [Python, Deep Learning, TensorFlow, Keras]
# 8                 [JavaScript, React, Redux, Node.js]
# 9               [SQL, Data Analysis, Power BI, Excel]
# 10             [Python, Scrapy, Beautiful Soup, APIs]
# 11               [Java, Spring Boot, JPA, PostgreSQL]
# 12            [JavaScript, Angular, TypeScript, HTML]
# 13         [C++, Algorithms, Data Structures, Python]
# 14                [DevOps, CI/CD, Jenkins, Terraform]
# 15   [Python, Machine Learning, Scikit-learn, Pandas]
# ...

# %%
import pandas as pd

# Generate sample data for the dataset
data = {
    "Resume Skills": [
        ["Python", "Machine Learning", "Data Analysis"],
        ["Java", "Hibernate"],
        # Add more sample resumes as needed
    ],
    "Job Description Skills": [
        ["Python", "Machine Learning", "SQL", "Data Analysis", "Java"],
        ["Java", "Spring", "MySQL", "Hibernate"],
        # Add more job descriptions as needed
    ],
}

# Create DataFrame
df = pd.DataFrame(data)

# Function to calculate match score and missing skills
def calculate_match_score_and_missing(resume_skills, job_skills):
    resume_set = set(resume_skills)
    job_set = set(job_skills)
    
    common_skills = resume_set.intersection(job_set)
    missing_skills = job_set - resume_set  # Skills in job description but not in resume
    total_skills = resume_set.union(job_set)
    
    if not total_skills:  # Prevent division by zero
        match_score = 0.0
    else:
        match_score = len(common_skills) / len(total_skills)
    
    return match_score, list(missing_skills)

# Apply the function to calculate match score and missing skills
df[['Match Score', 'Missing Skills']] = df.apply(
    lambda row: calculate_match_score_and_missing(row['Resume Skills'], row['Job Description Skills']), axis=1, result_type='expand'
)

# Save DataFrame to CSV
csv_file_path = 'C:/Users/Aswathy/OneDrive/Desktop/mini_proj/dataset_test.csv'
df.to_csv(csv_file_path, index=False)

# Check the updated DataFrame
print(df)
# Out:
#                                Resume Skills  \
# 0  [Python, Machine Learning, Data Analysis]
# 1                          [Java, Hibernate]
#
#                               Job Description Skills  Match Score  \
# 0  [Python, Machine Learning, SQL, Data Analysis,...          0.6
# 1                   [Java, Spring, MySQL, Hibernate]          0.5
#
#     Missing Skills
# 0      [SQL, Java]
# 1  [MySQL, Spring]

# %%
import pandas as pd

# Generate sample data for the dataset
data = {
    "Resume Skills": [
        ["Python", "Machine Learning"],
        [ "Spring", "Hibernate", "MySQL"],
        # Add more sample resumes as needed
    ],
    "Job Description Skills": [
        ["Python", "Machine Learning", "SQL", "Data Analysis", "Java"],
        ["Java", "Spring", "MySQL", "Hibernate", "Node.js"],
        # Add more job descriptions as needed
    ],
}

# Create DataFrame
df = pd.DataFrame(data)

# Recommendations mapping
recommendations_dict = {
    "SQL": "Consider taking an SQL course to improve your database skills.",
    "Hibernate": "Explore Hibernate tutorials to enhance your Java framework knowledge.",
    "Node.js": "Familiarize yourself with Node.js to strengthen your full-stack capabilities.",
    "DevOps": "Gain practical experience in DevOps tools to meet job requirements.",
    "Machine Learning": "Enhance your skills in Machine Learning through online courses.",
    "Cloud Platforms": "Get hands-on experience with cloud platforms to meet industry demands.",
    "TypeScript": "Learn TypeScript for better development practices in modern JavaScript.",
    "Deep Learning": "Study Deep Learning frameworks to advance your AI knowledge.",
    "Backend Development": "Strengthen your Node.js skills for backend development opportunities.",
    "Power BI": "Explore Power BI to enhance your data visualization capabilities.",
    "Web Scraping": "Practice web scraping techniques to gain practical insights.",
    "Microservices": "Deepen your understanding of Microservices architecture.",
    "C++": "Brush up on C++ algorithms for improved programming skills.",
    "Terraform": "Familiarize yourself with Terraform for better DevOps practices.",
    "Practical Machine Learning": "Strengthen your machine learning skills through practical projects.",
    "Software Architecture": "Explore Microservices concepts for better software architecture."
    # Add more skills and their recommendations as needed
}


# Function to calculate match score, missing skills, and recommendations
def calculate_match_score_and_missing(resume_skills, job_skills):
    resume_set = set(resume_skills)
    job_set = set(job_skills)
    
    common_skills = resume_set.intersection(job_set)
    missing_skills = job_set - resume_set  # Skills in job description but not in resume
    total_skills = resume_set.union(job_set)
    
    if not total_skills:  # Prevent division by zero
        match_score = 0.0
    else:
        match_score = len(common_skills) / len(total_skills)

    # Generate recommendations based on missing skills
    recommendations = []
    for skill in missing_skills:
        if skill in recommendations_dict:
            recommendations.append(recommendations_dict[skill])
    
    return match_score, list(missing_skills), recommendations

# Apply the function to calculate match score, missing skills, and recommendations
df[['Match Score', 'Missing Skills', 'Recommendations']] = df.apply(
    lambda row: calculate_match_score_and_missing(row['Resume Skills'], row['Job Description Skills']), axis=1, result_type='expand'
)

# Save DataFrame to CSV
csv_file_path = 'C:/Users/Aswathy/OneDrive/Desktop/mini_proj/dataset_test1.csv'
df.to_csv(csv_file_path, index=False)

# Check the updated DataFrame
print(df)
# Out:
#                 Resume Skills  \
# 0  [Python, Machine Learning]
# 1  [Spring, Hibernate, MySQL]
#
#                               Job Description Skills  Match Score  \
# 0  [Python, Machine Learning, SQL, Data Analysis,...          0.4
# 1          [Java, Spring, MySQL, Hibernate, Node.js]          0.6
#
#                Missing Skills  \
# 0  [SQL, Data Analysis, Java]
# 1             [Java, Node.js]
#
#                                      Recommendations
# 0  [Consider taking an SQL course to improve your...
# 1  [Familiarize yourself with Node.js to strength...

# %%
import pandas as pd

# Generate sample data for the dataset
data = {
    "Resume Skills": [
        [ "Data Analysis", "SQL"],
        ["Java", "Hibernate", "MySQL"],
        ["HTML", "JavaScript", "React"],
        ["Docker", "Kubernetes", "AWS"],
        ["Python", "Pandas", "Data Visualization"],
        ["Java", "REST", "Microservices", "Cloud"],
        ["HTML", "CSS", "Node.js", "Express"],
        [ "Deep Learning", "TensorFlow", "Keras"],
        ["JavaScript", "React", "Redux"],
        ["SQL", "Data Analysis", "Excel"],
        ["Python", "Scrapy", "Beautiful Soup", "APIs"],
        ["Java", "Spring Boot", "JPA", "PostgreSQL"],
        [ "Angular", "TypeScript"],
        ["C++", "Algorithms", "Data Structures", "Python"],
        ["DevOps", "Jenkins", "Terraform"],
        ["Python", "Machine Learning", "Scikit-learn", "Pandas"],
        ["Oracle", "SQL", "Microservices"],
        ["HTML", "CSS", "Bootstrap", "JavaScript"],
        ["Python", "Data Science", "Statistics", "Matplotlib"],
        ["Java", "JavaFX", "Maven", "JUnit"],
        ["JavaScript", "Vue.js", "Nuxt.js", "API Integration"],
        ["Python", "FastAPI", "Machine Learning", "Docker"],
        ["Java", "REST API", "Spring Cloud", "AWS"],
        ["HTML", "CSS", "React", "Redux"],
        ["Python", "Tableau", "Business Intelligence"],
        ["Java", "Eclipse", "JUnit", "MySQL"],
        ["Python", "Flask", "APIs", "SQLAlchemy"],
        ["JavaScript", "Node.js", "Express", "MongoDB"],
        ["Python", "NLP", "SpaCy", "Text Analysis"],
        ["Java", "Struts", "Hibernate", "SQL"],
        ["HTML", "CSS", "JavaScript", "Frontend Development"],
        ["Python", "Big Data", "Spark", "Hadoop"],
        ["Java", "Kafka", "Microservices", "Spring"],
        ["Python", "Data Cleaning", "Pandas", "NumPy"],
        ["JavaScript", "API Development", "Frontend"],
        ["Java", "Web Development","Tomcat"],
        ["Python", "Statistical Analysis", "Data Mining"],
        ["Java", "Spring MVC", "Oracle"],
        ["HTML", "CSS", "JavaScript", "Responsive Design"],
        ["Python", "Data Wrangling", "Pandas", "NLP"],
        ["Java", "Golang", "Cloud", "Microservices"],
        ["JavaScript", "Sass", "Vue.js"],
        ["Python", "ML Ops", "Deployment", "AWS"],
        [ "Spring Framework", "MongoDB", "REST API"],
        ["Python","Java"],
        ["Python", "Data Visualization"],
        ["Java", "JSP", "Servlets", "MySQL"],
        ["JavaScript", "WebSockets", "Node.js"],
        ["Python", "Statistical Modeling", "Machine Learning"],
        ["JavaScript", "Machine Learning", "Statistics"],
        ["Python", "Machine Learning"],
        ["Java", "Spring", "Hibernate", "MySQL"],
        ["JavaScript", "HTML", "CSS"],
        ["PHP", "MySQL", "WordPress"],
        ["Bootstrap", "HTML", "CSS"],
        ["C++", "Data Structures", "Algorithms"],
        ["Node.js", "Express", "MongoDB"],
        ["Ruby", "Ruby on Rails", "SQL"],
        ["C#", ".NET", "SQL Server"],
        ["Swift", "iOS Development"],
        ["Kotlin", "Android Development"],
        ["R", "Statistics", "Data Visualization"],
        ["TensorFlow", "Deep Learning"],
        ["Git", "GitHub", "Version Control"],
        ["Docker", "Kubernetes", "DevOps"],
        ["Power BI", "Tableau", "Data Analysis"],
        ["Agile", "Scrum", "Project Management"],
        ["SEO", "Digital Marketing", "Content Writing"],
        ["React", "Redux", "JavaScript"],
        ["Angular", "TypeScript", "Frontend Development"],
        ["Java", "JavaFX", "Spring Boot"],
        ["Swift", "Objective-C", "iOS"],
        ["Unity", "Game Development", "C#"],
        ["Salesforce", "CRM", "Cloud Computing"],
        ["PHP", "Laravel", "Web Development"],
        ['Unreal Engine', 'Google Cloud', 'DevOps', 'Data Mining'],
        ['Kubernetes', 'NumPy', 'Django', 'TensorFlow', 'PostgreSQL', 'DevOps', 'Digital Marketing'],
        ['Unreal Engine', 'Tomcat', 'ML Ops', 'Postman', 'Ruby on Rails', 'C++', 'Data Visualization'],
        ['WebSockets', 'CI/CD', 'JSP', 'Data Science', 'SQLAlchemy', 'Kotlin'],
        ['Statistics', 'NumPy', 'Data Mining'],
        ['JUnit', 'Data Wrangling', 'FastAPI', 'Redux', 'Data Mining', 'React', 'Cloud Computing'],
        ['Scrapy', 'Game Development', 'HTML', 'Scikit-learn'],
        ['Data Mining', 'Scrapy', 'Hibernate', 'Deep Learning', 'iOS Development', 'Microservices', 'Spring Boot'],
        ['Angular', 'GraphQL', 'MySQL', 'JPA'],
        ['Data Wrangling', 'Ruby', 'Unreal Engine', 'Maven', 'Game Development', 'Postman', 'Scrapy'],
        ['Pandas', 'TensorFlow', 'Beautiful Soup', 'SQLAlchemy', 'Android Development', 'Figma'],
        ['C#', 'Swift', 'HTML', 'Keras'],
        ['Kafka', 'NumPy', 'Express', 'Figma'],
        ['Objective-C', 'Ruby on Rails', 'iOS Development', 'Figma', 'Jenkins', 'Responsive Design', 'C++'],
        ['Kotlin', 'Django', 'Python', 'Cucumber', 'Selenium', 'Web Scraping', 'WebSockets'],
        ['PHP', 'Data Visualization', 'JavaScript', 'Data Science', 'Unreal Engine', 'Unity', 'Web Scraping'],
        ['Vue.js', 'GraphQL', 'Microservices', 'C#'],
        ['Oracle', 'Swift', 'Power BI', 'Kafka', 'Web Scraping', 'APIs', 'Scrapy'],
        ['Hibernate', 'Responsive Design', 'Big Data', 'JUnit', 'Machine Learning', 'Flask', 'Azure'],
        ['NumPy', 'Git', 'Web Scraping'],
        ['R', 'JUnit', 'Unreal Engine', 'Ruby', 'Data Analysis', 'Git', 'Kubernetes'],
        ['Ruby on Rails', 'Kubernetes', 'Bootstrap', 'Ruby', 'Swift', 'Angular'],
        ['Azure', 'Pandas', 'UI/UX', 'Tomcat', 'SQL', 'NumPy'],
        ['JPA', 'Data Science', 'Scikit-learn', 'Servlets', 'Unreal Engine', 'Swift'],
        ['JavaScript', 'Web Scraping', 'NumPy', 'C++', 'APIs'],
        ['DevOps', 'JSP', 'Hadoop'],
        ['Kafka', 'iOS Development', 'Machine Learning', 'Game Development', 'API Integration', 'APIs', 'Express'],
        ['WebSockets', 'GitHub', 'CSS', 'Java'],
        ['Maven', 'Scrum', 'Spark', 'Unity', 'GitHub'],
        ['TensorFlow', 'MySQL', 'JSP', 'Web Scraping', 'Maven', 'Digital Marketing'],
        ['Data Visualization', 'Angular', 'Shopify', 'iOS Development', 'Ruby on Rails'],
        ['Java', 'Git', 'Machine Learning', 'Hadoop'],
        ['JavaScript', 'Data Analysis', 'Pandas', 'Shopify', 'HTML'],
        ['Deep Learning', 'Jenkins', 'Agile', 'API Integration', 'JSP', 'R'],
        ['NumPy', 'Terraform', 'Cloud Computing', 'Data Visualization', 'Power BI', 'Responsive Design', 'APIs'],
        ['JSP', 'Postman', 'Scikit-learn', 'AWS', 'APIs', 'SQLAlchemy', 'Statistics'],
        ['Jenkins', 'NumPy', 'TensorFlow', 'Hibernate', 'UI/UX', 'JPA'],
        ['Game Development', 'Web Scraping', 'REST API', 'Deep Learning', 'Cloud Computing', 'PHP'],
        ['Data Science', 'WebSockets', 'Azure', 'Spring Boot', 'Ruby', 'iOS Development'],
        ['Servlets', 'Swift', 'SEO', 'CI/CD', 'Angular', 'Responsive Design', 'Flask'],
        ['PostgreSQL', 'Power BI', 'Web Scraping', 'Express', 'Laravel', 'Scrum'],
        ['iOS Development', 'Hibernate', 'Kotlin', 'TypeScript', 'Data Analysis', 'C++'],
        ['ML Ops', 'APIs', 'API Integration', 'Figma', 'Python', 'SQL', 'Spring'],
        ['Deep Learning', 'APIs', 'Kubernetes'],
        ['MongoDB', 'Data Mining', 'Spring Boot', 'Express', 'Vue.js', 'Python', 'FastAPI'],
        ['Tableau', 'Docker', 'React', 'Selenium', 'Pandas', 'Node.js'],
        ['UI/UX', 'Cucumber', 'APIs', 'JavaScript', 'Java', 'Spring', 'Node.js'],
        ['Cucumber', 'Flask', 'Vue.js', 'C#'],
        ['React', 'FastAPI', 'Figma', 'DevOps'],
        ['Vue.js', 'Kubernetes', 'Jenkins', 'FastAPI', 'Selenium'],
        ['Kubernetes', 'Angular', 'Java', 'API Integration'],
        ['MySQL', 'Postman', 'Scikit-learn', 'Power BI', 'C#'],
        ['MySQL', 'Hadoop', 'JavaScript', 'MongoDB']
    ],
    "Job Description Skills":[
        ['Data Science', 'iOS Development', 'Shopify', 'Data Mining', 'Java'],
['Postman', 'Hibernate', 'Redux', 'React', 'Kubernetes', 'Figma', 'Servlets'],
['Django', 'Angular', 'Scrum', 'iOS Development', 'Unreal Engine', 'FastAPI', 'Cucumber', 'Jira'],
['Cloud Computing', 'Scrum', 'JUnit', 'C#', 'Microservices', 'Unity', 'SQLAlchemy', 'Big Data'],
['WebSockets', 'Git', 'MongoDB', 'Data Mining', 'Data Science'],
['Machine Learning', 'Spring Boot', 'Game Development', 'React', 'Kafka', 'C++', 'Python', 'Node.js'],
['Figma', 'Scikit-learn', 'Cucumber', 'ML Ops'],
['Scrum', 'Scrapy', 'PHP', 'Cloud Computing', 'Oracle', 'GitHub', 'Jenkins', 'Terraform'],
['Data Visualization', 'Unity', 'NumPy', 'MySQL'],
['CSS', 'Scikit-learn', 'Tableau', 'Django', 'Spark', 'Game Development'],
['JavaScript', 'CI/CD', 'Power BI', 'Agile', 'SQLAlchemy'],
['PostgreSQL', 'Beautiful Soup', 'Kafka', 'C#', 'JUnit'],
['Redux', 'Statistics', 'Kafka', 'Hadoop', 'Cloud Computing'],
['Angular', 'GraphQL', 'iOS Development', 'Big Data', 'Flask', 'FastAPI', 'REST API'],
['Data Mining', 'Postman', 'WebSockets', 'Objective-C', 'Selenium', 'MongoDB', 'Django', 'Big Data'],
['TensorFlow', 'TypeScript', 'JUnit', 'Data Science'],
['WordPress', 'Maven', 'Big Data', 'Unity', 'C++', 'TensorFlow', 'C#', 'Express'],
['Maven', 'Kafka', 'MySQL', 'Node.js', 'Data Analysis', 'iOS Development', 'Android Development'],
['PostgreSQL', 'Digital Marketing', 'Scikit-learn', 'Data Visualization', 'Flask', 'Docker', 'TypeScript'],
['NumPy', 'Cloud Computing', 'Laravel', 'WordPress', 'Angular', 'CI/CD'],
['SQLAlchemy', 'APIs', 'TypeScript', 'HTML', 'Statistical Modeling', 'Unreal Engine'],
['Ruby', 'Microservices', 'Flask', 'API Integration', 'APIs'],
['Azure', 'HTML', 'CSS', 'UI/UX', 'Java', 'React', 'Hadoop'],
['DevOps', 'Figma', 'JPA', 'Digital Marketing', 'Jira', 'Web Scraping'],
['Scrum', 'HTML', 'Angular', 'MongoDB', 'JavaScript', 'GitHub'],
['Kotlin', 'Spark', 'Tableau', 'Kubernetes', 'WordPress', 'JSP'],
['Machine Learning', 'Statistical Modeling', 'Redux', 'Shopify', 'PostgreSQL', 'Docker', 'AWS'],
['CSS', 'GraphQL', 'Statistical Modeling', 'NumPy', 'Google Cloud'],
['Hadoop', 'Spark', 'Tomcat', 'Figma', 'C++', 'Django', 'UI/UX'],
['Kafka', 'TensorFlow', 'C#', 'Ruby on Rails', 'Redux', 'Node.js', 'Agile', 'NumPy'],
['Agile', 'SQLAlchemy', 'C++', 'Statistics', 'Angular', 'Keras', 'API Integration', 'Servlets'],
['Hadoop', 'GitHub', 'Cloud Computing', 'Unity', 'FastAPI'],
['Web Scraping', 'C++', 'TypeScript', 'JavaScript', 'Angular'],
['Digital Marketing', 'APIs', 'TypeScript', 'API Integration', 'Data Mining', 'Unity'],
['Microservices', 'R', 'Laravel', 'Objective-C', 'NumPy'],
['Spark', 'DevOps', 'Responsive Design', 'AWS'],
['PHP', 'Flask', 'Agile', 'CSS', 'TensorFlow', 'Pandas', 'WordPress'],
['Spark', 'Scrum', 'Deep Learning', 'SEO', 'Oracle', 'Azure', 'React'],
['JPA', 'Statistics', 'C#', 'Figma', 'Game Development', 'Data Science', 'CSS', 'JavaScript'],
['Express', 'Java', 'JSP', 'CI/CD', 'Statistical Modeling'],
['JavaScript', 'SQLAlchemy', 'MySQL', 'Laravel', 'Postman', 'ML Ops'],
['GitHub', 'TypeScript', 'JUnit', 'Oracle', 'Machine Learning'],
['Google Cloud', 'Python', 'TypeScript', 'R', 'iOS Development'],
['TypeScript', 'Servlets', 'Data Visualization', 'Figma', 'DevOps', 'Spring Boot'],
['Ruby on Rails', 'Bootstrap', 'API Integration', 'Data Wrangling', 'Express', 'Agile', 'iOS Development'],
['Figma', 'Data Wrangling', 'Jira', 'Azure', 'Digital Marketing', 'Maven', 'R', 'Servlets'],
['Oracle', 'Spring Boot', 'Data Wrangling', 'Azure', 'JUnit', 'JavaScript'],
['UI/UX', 'ML Ops', 'NumPy', 'Objective-C'],
['AWS', 'Pandas', 'Flask', 'JUnit', 'TypeScript', 'TensorFlow', 'Spring Boot', 'Data Wrangling'],
['Flask', 'Scrum', 'DevOps', 'SQL', 'Oracle'],
['Unity', 'Power BI', 'SEO', 'DevOps', 'GitHub', 'HTML', 'Scrum', 'REST API'],
['React', 'Sass', 'Objective-C', 'Servlets', 'Tomcat', 'PHP', 'R'],
['Pandas', 'HTML', 'iOS Development', 'Maven', 'SQLAlchemy', 'WordPress'],
['Hibernate', 'Cloud Computing', 'Statistical Modeling', 'Swift', 'FastAPI', 'Keras'],
['NumPy', 'MySQL', 'Google Cloud', 'Data Mining', 'SQL', 'Oracle', 'SEO'],
['Terraform', 'WordPress', 'HTML', 'Web Scraping'],
['Ruby on Rails', 'Objective-C', 'Scrapy', 'APIs', 'Unreal Engine', 'Web Scraping', 'WordPress', 'Swift'],
['Python', 'SQLAlchemy', 'Maven', 'R', 'Flask'],
['Bootstrap', 'Hibernate', 'Laravel', 'Agile', 'SQLAlchemy', 'Game Development', 'Azure', 'Sass'],
['MySQL', 'Web Scraping', 'Kubernetes', 'C++', 'Azure', 'TypeScript', 'Java', 'UI/UX'],
['Ruby', 'Big Data', 'Kafka', 'Express', 'API Integration', 'JSP', 'Scikit-learn', 'GitHub'],
['Statistical Modeling', 'Node.js', 'JPA', 'Django', 'Tomcat', 'Terraform', 'FastAPI', 'Scikit-learn'],
['JUnit', 'PHP', 'APIs', 'C#', 'Redux'],
['Tomcat', 'Scikit-learn', 'Postman', 'TensorFlow'],
['FastAPI', 'AWS', 'Spring Boot', 'Express', 'Data Analysis', 'Tableau', 'React'],
['Data Science', 'TypeScript', 'Data Visualization', 'PHP'],
['SEO', 'Unity', 'Java', 'Terraform', 'Kafka'],
['APIs', 'Google Cloud', 'TypeScript', 'Azure', 'Agile', 'JavaScript', 'R', 'TensorFlow'],
['Scrapy', 'Sass', 'Python', 'Kubernetes', 'FastAPI'],
['JPA', 'Redux', 'UI/UX', 'Ruby', 'Postman', 'Docker'],
['Sass', 'HTML', 'Laravel', 'React', 'Data Wrangling'],
['Statistics', 'JavaScript', 'iOS Development', 'SQL', 'TensorFlow', 'Power BI'],
['HTML', 'Responsive Design', 'Ruby on Rails', 'Docker', 'Data Science', 'Bootstrap', 'JPA', 'Keras'],
['APIs', 'Objective-C', 'Pandas', 'WordPress', 'JSP', 'Scrapy', 'Cucumber', 'Data Wrangling'],
['React', 'GraphQL', 'Power BI', 'Unreal Engine', 'Hibernate'],
['SEO', 'Keras', 'Unreal Engine', 'Web Scraping', 'Unity', 'Jenkins', 'WordPress'],
['Jenkins', 'Machine Learning', 'REST API', 'Statistics', 'C++'],
['REST API', 'Tomcat', 'TensorFlow', 'HTML', 'APIs', 'UI/UX'],
['Flask', 'Scrapy', 'Game Development', 'Data Mining', 'Keras', 'CI/CD'],
['Machine Learning', 'JavaScript', 'Responsive Design', 'iOS Development', 'Kafka', 'Deep Learning', 'Maven'],
['Git', 'Spring Boot', 'Beautiful Soup', 'Scrapy'],
['C#', 'MySQL', 'Node.js', 'SEO', 'Beautiful Soup', 'Statistics'],
['SEO', 'SQLAlchemy', 'Scikit-learn', 'Scrum', 'Deep Learning', 'Scrapy'],
['Game Development', 'Django', 'Jenkins', 'Data Wrangling', 'HTML', 'Maven', 'Microservices', 'Servlets'],
['UI/UX', 'Spring Boot', 'Android Development', 'Oracle', 'Jira', 'SQL', 'Postman'],
['Unity', 'NumPy', 'AWS', 'PHP', 'REST API', 'API Integration', 'Django', 'Beautiful Soup'],
['Jenkins', 'Figma', 'Machine Learning', 'Power BI', 'Java', 'C#', 'Deep Learning', 'Objective-C'],
['Tableau', 'Java', 'FastAPI', 'Digital Marketing', 'Machine Learning', 'Keras', 'Google Cloud', 'WordPress'],
['Jira', 'PostgreSQL', 'CI/CD', 'PHP', 'Jenkins', 'Django', 'APIs', 'Beautiful Soup'],
['Deep Learning', 'Data Analysis', 'Keras', 'Django', 'FastAPI', 'JavaScript', 'Statistical Modeling'],
['Figma', 'Machine Learning', 'Scrapy', 'REST API', 'Flask', 'C++'],
['WebSockets', 'HTML', 'Cloud Computing', 'Power BI'],
['Scrum', 'JavaScript', 'FastAPI', 'Spring Boot', 'Git'],
['Jira', 'API Integration', 'Java', 'Cloud Computing'],
['Machine Learning', 'MySQL', 'Pandas', 'Selenium', 'JavaScript', 'Unity'],
['Postman', 'Java', 'Agile', 'Game Development', 'Data Wrangling', 'API Integration', 'Flask', 'Jenkins'],
['Tableau', 'CI/CD', 'Power BI', 'Google Cloud'],
['Machine Learning', 'FastAPI', 'Kubernetes', 'PostgreSQL', 'C#', 'HTML'],
['Power BI', 'Deep Learning', 'Jenkins', 'NumPy', 'Flask', 'FastAPI', 'C++', 'PHP'],
['FastAPI', 'API Integration', 'Java', 'JavaScript', 'Unity'],
['Kubernetes', 'API Integration', 'Data Mining', 'Machine Learning', 'JSP'],
['Data Analysis', 'Flask', 'JSP', 'Java', 'JavaScript'],
['Pandas', 'Beautiful Soup', 'Java', 'Google Cloud', 'FastAPI'],
['Postman', 'Cucumber', 'Game Development', 'Pandas', 'Objective-C'],
['Game Development', 'Spring Boot', 'PostgreSQL', 'Data Analysis', 'TensorFlow', 'Scrapy', 'Figma', 'Ruby'],
['Jira', 'Deep Learning', 'Unity', 'CI/CD', 'Django', 'JavaScript'],
['Java', 'Power BI', 'Game Development', 'Hadoop'],
['Flask', 'JavaScript', 'HTML', 'Node.js', 'Spring Boot'],
['Cucumber', 'Java', 'Power BI', 'GitHub'],
['Game Development', 'Unity', 'Figma', 'Cucumber'],
['FastAPI', 'Machine Learning', 'Java', 'Power BI', 'Data Analysis'],
['Pandas', 'Data Mining', 'Java', 'Git'],
['JavaScript', 'Machine Learning', 'Deep Learning', 'Ruby', 'Cloud Computing', 'PostgreSQL', 'Flask'],
['Kubernetes', 'Django', 'FastAPI', 'TensorFlow', 'Oracle', 'Game Development'],
['Data Wrangling', 'Data Analysis', 'Machine Learning', 'Java', 'FastAPI'],
['Power BI', 'Data Wrangling', 'Deep Learning', 'Data Science'],
['Beautiful Soup', 'API Integration', 'Flask', 'Java', 'Machine Learning'],
['JavaScript', 'C#', 'Node.js', 'WebSockets'],
['Ruby on Rails', 'React', 'Java', 'Deep Learning', 'Game Development'],
['Python', 'HTML', 'JavaScript', 'Kubernetes', 'PostgreSQL'],
['Java', 'Data Wrangling', 'Git', 'Cloud Computing', 'Selenium'],
['Java', 'Node.js', 'API Integration', 'FastAPI', 'Machine Learning'],
['Deep Learning', 'Scrapy', 'Python', 'Flask'],
['WebSockets', 'Power BI', 'JavaScript', 'PHP', 'Data Science'],
['Selenium', 'Postman', 'Beautiful Soup', 'JavaScript', 'Spring Boot', 'iOS Development'],
['Machine Learning', 'FastAPI', 'Java', 'Django', 'PostgreSQL'],
['Flask', 'Java', 'JavaScript', 'Unity', 'WebSockets'],
['Node.js', 'Java', 'Data Analysis', 'Ruby']
    ],
}

print(len(data["Resume Skills"]))
print(len(data["Job Description Skills"]))
# Out:
# 128
# 128
